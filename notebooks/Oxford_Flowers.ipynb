# %%
import sys
sys.path.append('../src/')

# %load_ext autoreload
# %autoreload 2
# Importing our custom module(s)
import losses
import utils

# %%
import os
import itertools
import re
import numpy as np
import pandas as pd
# PyTorch
import torch

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford_Flowers'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [102, 510, 1020]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'nonlearned'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_Oxford_Flowers'
weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
count = -1
for lr_0, n, random_state, weight_decay in itertools.product(lr_0s, ns, random_states, weight_decays):
    count += 1
    model_name = f'{prior_type}_lr_0={lr_0}_n={n}_random_state={random_state}_weight_decay={weight_decay}'
    print(f'    "python ../src/main_OXFL.py --bb_weight_decay={weight_decay} --clf_weight_decay={weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --random_state={random_state} --tune --wandb --wandb_project=\'{wandb_project}\'"')
print(count)
# Out:
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='nonlearned_lr_0=0.1_n=102_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='nonlearned_lr_0=0.1_n=510_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='nonlearned_lr_0=0.1_n=1020_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='nonlearned_lr_0=0.01_n=102_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='nonlearned_lr_0=0.01_n=510_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='nonlearned_lr_0=0.01_n=1020_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='nonlearned_lr_0=0.01_n=1020_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='nonlearned_lr_0=0.01_n=1020_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='nonlearned_lr_0=0.01_n=1020_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='nonlearned_lr_0=0.01_n=1020_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='nonlearned_lr_0=0.01_n=1020_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
# ...
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='nonlearned_lr_0=0.0001_n=510_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='nonlearned_lr_0=0.0001_n=510_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='nonlearned_lr_0=0.0001_n=510_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='nonlearned_lr_0=0.0001_n=510_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='nonlearned_lr_0=0.0001_n=510_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='nonlearned_lr_0=0.0001_n=510_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='nonlearned_lr_0=0.0001_n=510_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='nonlearned_lr_0=0.0001_n=510_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='nonlearned_lr_0=0.0001_n=510_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='nonlearned_lr_0=0.0001_n=510_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='nonlearned_lr_0=0.0001_n=510_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='nonlearned_lr_0=0.0001_n=510_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='nonlearned_lr_0=0.0001_n=510_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='nonlearned_lr_0=0.0001_n=1020_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
# 215

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford_Flowers'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [102, 510, 1020]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'adapted'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_Oxford_Flowers'
weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
count = -1
for lr_0, n, random_state, weight_decay in itertools.product(lr_0s, ns, random_states, weight_decays):
    count += 1
    model_name = f'{prior_type}_lr_0={lr_0}_n={n}_random_state={random_state}_weight_decay={weight_decay}'
    print(f'    "python ../src/main_OXFL.py --bb_weight_decay={weight_decay} --clf_weight_decay={weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune --wandb --wandb_project=\'{wandb_project}\'"')
print(count)
# Out:
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='adapted_lr_0=0.1_n=102_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='adapted_lr_0=0.1_n=510_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='adapted_lr_0=0.1_n=1020_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='adapted_lr_0=0.01_n=102_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='adapted_lr_0=0.01_n=510_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='adapted_lr_0=0.01_n=1020_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='adapted_lr_0=0.01_n=1020_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
# ...
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='adapted_lr_0=0.0001_n=510_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='adapted_lr_0=0.0001_n=510_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='adapted_lr_0=0.0001_n=510_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='adapted_lr_0=0.0001_n=510_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='adapted_lr_0=0.0001_n=510_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='adapted_lr_0=0.0001_n=510_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='adapted_lr_0=0.0001_n=510_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='adapted_lr_0=0.0001_n=510_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='adapted_lr_0=0.0001_n=510_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='adapted_lr_0=0.0001_n=510_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='adapted_lr_0=0.0001_n=510_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='adapted_lr_0=0.0001_n=510_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
#     "python ../src/main_OXFL.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='adapted_lr_0=0.0001_n=1020_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford_Flowers'"
# 215

# %%
bb_weight_decays = np.logspace(0, 9, num=10)
clf_weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford_Flowers'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [102, 510, 1020]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'LearnedPriorLR'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_OXFL'
count = -1
for bb_weight_decay, clf_weight_decay, lr_0, n, random_state in itertools.product(bb_weight_decays, clf_weight_decays, lr_0s, ns, random_states):
    count += 1
    model_name = f'{prior_type}_bb_weight_decay={bb_weight_decay}_clf_weight_decay={clf_weight_decay}_lr_0={lr_0}_n={n}_random_state={random_state}'
    print(f'    "python ../src/main_OXFL.py --bb_weight_decay={bb_weight_decay} --clf_weight_decay={clf_weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune --wandb --wandb_project=\'{wandb_project}\'"')
print(count)
# Out:
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.1_n=102_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.1_n=102_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.1_n=102_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.1_n=510_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.1_n=510_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.1_n=510_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.1_n=1020_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.1_n=1020_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.1_n=1020_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.01_n=102_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.01_n=102_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.01_n=102_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.01_n=510_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.01_n=510_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.01_n=510_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.01_n=1020_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.01_n=1020_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.01_n=1020_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.001_n=102_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.001_n=102_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.001_n=102_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.001_n=510_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.001_n=510_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.001_n=510_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.001_n=1020_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.001_n=1020_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.001_n=1020_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.0001_n=102_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.0001_n=102_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.0001_n=102_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.0001_n=510_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.0001_n=510_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.0001_n=510_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.0001_n=1020_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.0001_n=1020_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.0001_n=1020_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.1_n=102_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.1_n=102_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.1_n=102_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.1_n=510_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.1_n=510_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.1_n=510_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.1_n=1020_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.1_n=1020_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.1_n=1020_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.01_n=102_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.01_n=102_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.01_n=102_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.01_n=510_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.01_n=510_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.01_n=510_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.01_n=1020_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.01_n=1020_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.01_n=1020_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.001_n=102_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.001_n=102_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.001_n=102_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.001_n=510_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.001_n=510_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.001_n=510_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.001_n=1020_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.001_n=1020_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.001_n=1020_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.0001_n=102_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.0001_n=102_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.0001_n=102_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.0001_n=510_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.0001_n=510_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.0001_n=510_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.0001_n=1020_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.0001_n=1020_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.0001_n=1020_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.1_n=102_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.1_n=102_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.1_n=102_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.1_n=510_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.1_n=510_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.1_n=510_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.1_n=1020_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.1_n=1020_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.1_n=1020_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.01_n=102_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.01_n=102_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.01_n=102_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.01_n=510_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.01_n=510_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.01_n=510_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
# ...
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.1 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.1_n=1020_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.01_n=102_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.01_n=102_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.01_n=102_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.01_n=510_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.01_n=510_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.01_n=510_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.01_n=1020_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.01_n=1020_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.01 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.01_n=1020_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.001_n=102_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.001_n=102_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.001_n=102_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.001_n=510_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.001_n=510_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.001_n=510_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.001_n=1020_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.001_n=1020_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.001_n=1020_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.0001_n=102_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.0001_n=102_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=102 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.0001_n=102_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.0001_n=510_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.0001_n=510_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=510 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.0001_n=510_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.0001_n=1020_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.0001_n=1020_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_OXFL'"
#     "python ../src/main_OXFL.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford_Flowers' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers' --lr_0=0.0001 --n=1020 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.0001_n=1020_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_OXFL'"
# 2159

# %%
def get_df(path):
    df = pd.read_csv(path, index_col='Unnamed: 0')
    return df

def get_val_nll(df):
    return df.val_or_test_nll.values[-1]

def get_val_acc1(df):
    if 'val_or_test_acc' in df.columns:
        return df.val_or_test_acc.values[-1]
    elif 'val_or_test_acc1' in df.columns:
        return df.val_or_test_acc1.values[-1]

# %%
def get_best_hyperparams(
    bb_weight_decays, 
    clf_weight_decays, 
    experiments_path, # Gets best hyperparameters from experiments_path
    lr_0s, 
    ns, 
    prior_type, # Gets best hyperparameters for a single prior_type
    random_states, 
    weight_decays
):
    hyperparam_names = ['bb_weight_decay', 'clf_weight_decay', 'lr_0', 'n', 'random_state', 'weight_decay']
    columns = ['model_name', 'n', 'prior_type', 'random_state', 'val_acc1', 'val_nll']
    df = pd.DataFrame(columns=columns)
    
    for hyperparams in itertools.product(bb_weight_decays, clf_weight_decays, lr_0s, ns, random_states, weight_decays):
        model_name = f'{prior_type}_' + '_'.join(f'{hyperparam_name}={hyperparam}' for hyperparam_name, hyperparam in zip(hyperparam_names, hyperparams) if hyperparam is not None)
        bb_weight_decay, clf_weight_decay, lr_0, n, random_state, weight_decay = hyperparams
        if not os.path.exists(f'{experiments_path}/{model_name}.csv'):
            print(model_name)
            pass
        else:
            temp_df = get_df(f'{experiments_path}/{model_name}.csv')
            val_acc1 = get_val_acc1(temp_df)
            val_nll = get_val_nll(temp_df)
            df.loc[df.shape[0]] = [model_name, n, prior_type, random_state, val_acc1, val_nll]
                    
    min_indices = df.groupby(['n', 'random_state'])['val_nll'].idxmin()
    df = df.loc[min_indices].reset_index(drop=True)
    #max_indices = df.groupby(['n', 'random_state'])['val_acc1'].idxmax()
    #df = df.loc[max_indices].reset_index(drop=True)
                    
    return df
                    
def get_results(
    df,
    experiments_path
):
    columns = ['model_name', 'n', 'prior_type', 'random_state', 'test_acc1', 'test_nll']
    results_df = pd.DataFrame(columns=columns)
    
    for row_index, row in df.iterrows():
        model_name = row.model_name
        prior_type, n, random_state = row.prior_type, row.n, row.random_state
        if not os.path.exists(f'{experiments_path}/{model_name}.csv'):
            #print(model_name)
            pass
        else:
            temp_df = get_df(f'{experiments_path}/{model_name}.csv')
            test_acc1 = get_val_acc1(temp_df)
            test_nll = get_val_nll(temp_df)
            condition = (results_df['n']==n)&(results_df['random_state']==random_state)
            if len(results_df[condition]) == 0:
                results_df.loc[results_df.shape[0]] = [model_name, n, prior_type, random_state, test_acc1, test_nll]
    
    return results_df

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford_Flowers'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [102, 510, 1020]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'nonlearned'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_Oxford_Flowers'
weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]

std_prior = get_best_hyperparams([None], [None], experiments_path, lr_0s, ns, prior_type, random_states, weight_decays)
std_prior
# Out:
#                                           model_name     n  prior_type  \
# 0  nonlearned_lr_0=0.001_n=102_random_state=1001_...   102  nonlearned
# 1  nonlearned_lr_0=0.001_n=102_random_state=2001_...   102  nonlearned
# 2  nonlearned_lr_0=0.01_n=102_random_state=3001_w...   102  nonlearned
# 3  nonlearned_lr_0=0.01_n=510_random_state=1001_w...   510  nonlearned
# 4  nonlearned_lr_0=0.01_n=510_random_state=2001_w...   510  nonlearned
# 5  nonlearned_lr_0=0.01_n=510_random_state=3001_w...   510  nonlearned
# 6  nonlearned_lr_0=0.01_n=1020_random_state=1001_...  1020  nonlearned
# 7  nonlearned_lr_0=0.01_n=1020_random_state=2001_...  1020  nonlearned
# 8  nonlearned_lr_0=0.01_n=1020_random_state=3001_...  1020  nonlearned
#
#    random_state  val_acc1   val_nll
# 0          1001  0.000000  4.989253
# 1          2001  0.000000  4.917150
# 2          3001  0.000000  4.973053
# 3          1001  0.754902  0.999892
# 4          2001  0.745098  0.847915
# 5          3001  0.725490  1.295717
# 6          1001  0.857843  0.460927
# 7          2001  0.838235  0.618836
# 8          3001  0.823529  0.740744

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford_Flowers'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/retrained_Oxford_Flowers'
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
wandb_project = 'retrained_Oxford_Flowers'

pattern = re.compile(r'(\w+)_lr_0=([\d.]+)_n=(\d+)_random_state=(\d+)_weight_decay=([\d.]+(?:e[-+]?\d+)?)')
for row_index, row in std_prior.iterrows():
    model_name = row.model_name
    match = pattern.match(model_name)
    prior_type, lr_0, n, random_state, weight_decay = match.groups()
    if not os.path.exists(f'{experiments_path}/{model_name}.csv'):
        print(f'    "python ../src/main_OXFL.py --bb_weight_decay={weight_decay} --clf_weight_decay={weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save --wandb --wandb_project=\'{wandb_project}\'"')

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford_Flowers'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [102, 510, 1020]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'adapted'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_Oxford_Flowers'
weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]

learned_prior_iso = get_best_hyperparams([None], [None], experiments_path, lr_0s, ns, prior_type, random_states, weight_decays)
learned_prior_iso
# Out:
#                                           model_name     n prior_type  \
# 0  adapted_lr_0=0.01_n=102_random_state=1001_weig...   102    adapted
# 1  adapted_lr_0=0.1_n=102_random_state=2001_weigh...   102    adapted
# 2  adapted_lr_0=0.1_n=102_random_state=3001_weigh...   102    adapted
# 3  adapted_lr_0=0.01_n=510_random_state=1001_weig...   510    adapted
# 4  adapted_lr_0=0.01_n=510_random_state=2001_weig...   510    adapted
# 5  adapted_lr_0=0.01_n=510_random_state=3001_weig...   510    adapted
# 6  adapted_lr_0=0.01_n=1020_random_state=1001_wei...  1020    adapted
# 7  adapted_lr_0=0.01_n=1020_random_state=2001_wei...  1020    adapted
# 8  adapted_lr_0=0.1_n=1020_random_state=3001_weig...  1020    adapted
#
#    random_state  val_acc1   val_nll
# 0          1001  0.000000  4.811606
# 1          2001  0.000000  4.780711
# 2          3001  0.000000  4.733363
# 3          1001  0.754902  0.999892
# 4          2001  0.725490  0.856042
# 5          3001  0.696078  1.315177
# 6          1001  0.857843  0.457699
# 7          2001  0.843137  0.631958
# 8          3001  0.848039  0.652592

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford_Flowers'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/retrained_Oxford_Flowers'
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
wandb_project = 'retrained_Oxford_Flowers'

pattern = re.compile(r'(\w+)_lr_0=([\d.]+)_n=(\d+)_random_state=(\d+)_weight_decay=([\d.]+(?:e[-+]?\d+)?)')
for row_index, row in learned_prior_iso.iterrows():
    model_name = row.model_name
    match = pattern.match(model_name)
    prior_type, lr_0, n, random_state, weight_decay = match.groups()
    if not os.path.exists(f'{experiments_path}/{model_name}.csv'):
        print(f'    "python ../src/main_OXFL.py --bb_weight_decay={weight_decay} --clf_weight_decay={weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save --wandb --wandb_project=\'{wandb_project}\'"')

# %%
bb_weight_decays = np.logspace(0, 9, num=10)
clf_weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford_Flowers'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford_Flowers'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [102, 510, 1020]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'LearnedPriorLR'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_Oxford_Flowers'
weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]

learned_prior_lr = get_best_hyperparams(bb_weight_decays, clf_weight_decays, experiments_path, lr_0s, ns, prior_type, random_states, [None])
learned_prior_lr
# Out:
#                                           model_name     n      prior_type  \
# 0  LearnedPriorLR_bb_weight_decay=1000000000.0_cl...   102  LearnedPriorLR
# 1  LearnedPriorLR_bb_weight_decay=1000000000.0_cl...   102  LearnedPriorLR
# 2  LearnedPriorLR_bb_weight_decay=100000.0_clf_we...   102  LearnedPriorLR
# 3  LearnedPriorLR_bb_weight_decay=1000.0_clf_weig...   510  LearnedPriorLR
# 4  LearnedPriorLR_bb_weight_decay=1000000.0_clf_w...   510  LearnedPriorLR
# 5  LearnedPriorLR_bb_weight_decay=10000000.0_clf_...   510  LearnedPriorLR
# 6  LearnedPriorLR_bb_weight_decay=1000000.0_clf_w...  1020  LearnedPriorLR
# 7  LearnedPriorLR_bb_weight_decay=10000.0_clf_wei...  1020  LearnedPriorLR
# 8  LearnedPriorLR_bb_weight_decay=10000.0_clf_wei...  1020  LearnedPriorLR
#
#    random_state  val_acc1   val_nll
# 0          1001  0.000000  4.752750
# 1          2001  0.000000  4.725802
# 2          3001  0.000000  4.700243
# 3          1001  0.774510  0.928347
# 4          2001  0.725490  0.846020
# 5          3001  0.735294  1.302512
# 6          1001  0.843137  0.461606
# 7          2001  0.852941  0.594523
# 8          3001  0.833333  0.641673

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford_Flowers'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/retrained_Oxford_Flowers'
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
wandb_project = 'retrained_Oxford_Flowers'

pattern = re.compile(r'(\w+)_bb_weight_decay=([\d.]+)_clf_weight_decay=([\d.]+(?:e[-+]?\d+)?)_lr_0=([\d.]+)_n=(\d+)_random_state=(\d+)')
for row_index, row in learned_prior_lr.iterrows():
    model_name = row.model_name
    match = pattern.match(model_name)
    prior_type, bb_weight_decay, clf_weight_decay, lr_0, n, random_state = match.groups()
    if not os.path.exists(f'{experiments_path}/{model_name}.csv'):
        print(f'    "python ../src/main_OXFL.py --bb_weight_decay={bb_weight_decay} --clf_weight_decay={clf_weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save --wandb --wandb_project=\'{wandb_project}\'"')

# %%
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/retrained_Oxford_Flowers'
std_prior_results = get_results(std_prior, experiments_path)
learned_prior_iso_results = get_results(learned_prior_iso, experiments_path)
learned_prior_lr_results = get_results(learned_prior_lr, experiments_path)
results = pd.concat([std_prior_results, learned_prior_iso_results, learned_prior_lr_results])
results
# Out:
#                                           model_name     n      prior_type  \
# 0  nonlearned_lr_0=0.001_n=102_random_state=1001_...   102      nonlearned
# 1  nonlearned_lr_0=0.001_n=102_random_state=2001_...   102      nonlearned
# 2  nonlearned_lr_0=0.01_n=102_random_state=3001_w...   102      nonlearned
# 3  nonlearned_lr_0=0.01_n=510_random_state=1001_w...   510      nonlearned
# 4  nonlearned_lr_0=0.01_n=510_random_state=2001_w...   510      nonlearned
# 5  nonlearned_lr_0=0.01_n=510_random_state=3001_w...   510      nonlearned
# 6  nonlearned_lr_0=0.01_n=1020_random_state=1001_...  1020      nonlearned
# 7  nonlearned_lr_0=0.01_n=1020_random_state=2001_...  1020      nonlearned
# 8  nonlearned_lr_0=0.01_n=1020_random_state=3001_...  1020      nonlearned
# 0  adapted_lr_0=0.01_n=102_random_state=1001_weig...   102         adapted
# 1  adapted_lr_0=0.1_n=102_random_state=2001_weigh...   102         adapted
# 2  adapted_lr_0=0.1_n=102_random_state=3001_weigh...   102         adapted
# 3  adapted_lr_0=0.01_n=510_random_state=1001_weig...   510         adapted
# 4  adapted_lr_0=0.01_n=510_random_state=2001_weig...   510         adapted
# 5  adapted_lr_0=0.01_n=510_random_state=3001_weig...   510         adapted
# 6  adapted_lr_0=0.01_n=1020_random_state=1001_wei...  1020         adapted
# 7  adapted_lr_0=0.01_n=1020_random_state=2001_wei...  1020         adapted
# 8  adapted_lr_0=0.1_n=1020_random_state=3001_weig...  1020         adapted
# 0  LearnedPriorLR_bb_weight_decay=1000000000.0_cl...   102  LearnedPriorLR
# 1  LearnedPriorLR_bb_weight_decay=1000000000.0_cl...   102  LearnedPriorLR
# 2  LearnedPriorLR_bb_weight_decay=100000.0_clf_we...   102  LearnedPriorLR
# 3  LearnedPriorLR_bb_weight_decay=1000.0_clf_weig...   510  LearnedPriorLR
# 4  LearnedPriorLR_bb_weight_decay=1000000.0_clf_w...   510  LearnedPriorLR
# 5  LearnedPriorLR_bb_weight_decay=10000000.0_clf_...   510  LearnedPriorLR
# 6  LearnedPriorLR_bb_weight_decay=1000000.0_clf_w...  1020  LearnedPriorLR
# 7  LearnedPriorLR_bb_weight_decay=10000.0_clf_wei...  1020  LearnedPriorLR
# 8  LearnedPriorLR_bb_weight_decay=10000.0_clf_wei...  1020  LearnedPriorLR
#
#    random_state  test_acc1  test_nll
# 0          1001   0.402119  3.399781
# 1          2001   0.405971  3.441620
# 2          3001   0.126149  4.234698
# 3          1001   0.784438  1.001429
# 4          2001   0.793378  0.961376
# 5          3001   0.790615  1.051639
# 6          1001   0.881129  0.580703
# 7          2001   0.881146  0.585888
# 8          3001   0.873750  0.608089
# 0          1001   0.347587  3.617058
# 1          2001   0.137550  4.528951
# 2          3001   0.090148  5.142247
# 3          1001   0.785246  1.002284
# 4          2001   0.791929  0.958409
# 5          3001   0.794422  1.026916
# 6          1001   0.882208  0.586185
# 7          2001   0.885554  0.576323
# 8          3001   0.891451  0.571242
# 0          1001   0.364694  3.586056
# 1          2001   0.392173  3.613402
# 2          3001   0.106156  4.807502
# 3          1001   0.747942  1.143384
# 4          2001   0.793797  0.954978
# 5          3001   0.794399  1.021018
# 6          1001   0.881636  0.579333
# 7          2001   0.884109  0.520431
# 8          3001   0.886992  0.531498

# %%
grouped_results = results.groupby(['n', 'prior_type']).agg(lambda x: tuple(x))
columns = ['test_acc1', 'test_nll']
for column in columns:
    grouped_results[f'{column}_mean'] = grouped_results[column].apply(lambda item: np.mean(item))
    grouped_results[f'{column}_std'] = grouped_results[column].apply(lambda item: np.std(item))
    grouped_results[f'{column}_min'] = grouped_results[column].apply(lambda item: np.min(item))
    grouped_results[f'{column}_max'] = grouped_results[column].apply(lambda item: np.max(item))
grouped_results = grouped_results.reset_index()
grouped_results
# Out:
#       n      prior_type                                         model_name  \
# 0   102  LearnedPriorLR  (LearnedPriorLR_bb_weight_decay=1000000000.0_c...
# 1   102         adapted  (adapted_lr_0=0.01_n=102_random_state=1001_wei...
# 2   102      nonlearned  (nonlearned_lr_0=0.001_n=102_random_state=1001...
# 3   510  LearnedPriorLR  (LearnedPriorLR_bb_weight_decay=1000.0_clf_wei...
# 4   510         adapted  (adapted_lr_0=0.01_n=510_random_state=1001_wei...
# 5   510      nonlearned  (nonlearned_lr_0=0.01_n=510_random_state=1001_...
# 6  1020  LearnedPriorLR  (LearnedPriorLR_bb_weight_decay=1000000.0_clf_...
# 7  1020         adapted  (adapted_lr_0=0.01_n=1020_random_state=1001_we...
# 8  1020      nonlearned  (nonlearned_lr_0=0.01_n=1020_random_state=1001...
#
#          random_state                                          test_acc1  \
# 0  (1001, 2001, 3001)  (0.3646940886974334, 0.3921734094619751, 0.106...
# 1  (1001, 2001, 3001)  (0.3475874960422516, 0.1375501751899719, 0.090...
# 2  (1001, 2001, 3001)  (0.4021194577217102, 0.4059711992740631, 0.126...
# 3  (1001, 2001, 3001)  (0.7479424476623535, 0.793796718120575, 0.7943...
# 4  (1001, 2001, 3001)  (0.7852461338043213, 0.7919294238090515, 0.794...
# 5  (1001, 2001, 3001)  (0.7844377160072327, 0.7933784127235413, 0.790...
# 6  (1001, 2001, 3001)  (0.8816355466842651, 0.8841086626052856, 0.886...
# 7  (1001, 2001, 3001)  (0.882207989692688, 0.885553777217865, 0.89145...
# 8  (1001, 2001, 3001)  (0.8811286091804504, 0.8811455965042114, 0.873...
#
#                                             test_nll  test_acc1_mean  \
# 0  (3.5860564038314973, 3.613401564297045, 4.8075...        0.287674
# 1  (3.617057904826469, 4.528951037470976, 5.14224...        0.191762
# 2  (3.3997814798378365, 3.441620494160424, 4.2346...        0.311413
# 3  (1.143384376756155, 0.9549783518288576, 1.0210...        0.778713
# 4  (1.0022837000564746, 0.9584089784500832, 1.026...        0.790533
# 5  (1.0014293385503894, 0.961376403621841, 1.0516...        0.789477
# 6  (0.5793327595617525, 0.520431114001732, 0.5314...        0.884245
# 7  (0.586185020925185, 0.5763231436216867, 0.5712...        0.886404
# 8  (0.5807032847180563, 0.5858882386544466, 0.608...        0.878675
#
#    test_acc1_std  test_acc1_min  test_acc1_max  test_nll_mean  test_nll_std  \
# 0       0.128842       0.106156       0.392173       4.002320      0.569459
# 1       0.111872       0.090148       0.347587       4.429419      0.626621
# 2       0.131011       0.126149       0.405971       3.692033      0.384102
# 3       0.021759       0.747942       0.794399       1.039794      0.078054
# 4       0.003874       0.785246       0.794422       0.995870      0.028333
# 5       0.003738       0.784438       0.793378       1.004815      0.036927
# 6       0.002189       0.881636       0.886992       0.543754      0.025561
# 7       0.003821       0.882208       0.891451       0.577917      0.006204
# 8       0.003482       0.873750       0.881146       0.591560      0.011878
#
#    test_nll_min  test_nll_max
# 0      3.586056      4.807502
# 1      3.617058      5.142247
# 2      3.399781      4.234698
# 3      0.954978      1.143384
# 4      0.958409      1.026916
# 5      0.961376      1.051639
# 6      0.520431      0.579333
# 7      0.571242      0.586185
# 8      0.580703      0.608089

# %%
grouped_results[['n', 'prior_type', 'test_acc1_mean', 'test_acc1_min', 'test_acc1_max']]
# Out:
#       n      prior_type  test_acc1_mean  test_acc1_min  test_acc1_max
# 0   102  LearnedPriorLR        0.287674       0.106156       0.392173
# 1   102         adapted        0.191762       0.090148       0.347587
# 2   102      nonlearned        0.311413       0.126149       0.405971
# 3   510  LearnedPriorLR        0.778713       0.747942       0.794399
# 4   510         adapted        0.790533       0.785246       0.794422
# 5   510      nonlearned        0.789477       0.784438       0.793378
# 6  1020  LearnedPriorLR        0.884245       0.881636       0.886992
# 7  1020         adapted        0.886404       0.882208       0.891451
# 8  1020      nonlearned        0.878675       0.873750       0.881146

# %%
grouped_results[['n', 'prior_type', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#       n      prior_type  test_nll_mean  test_nll_min  test_nll_max
# 0   102  LearnedPriorLR       4.002320      3.586056      4.807502
# 1   102         adapted       4.429419      3.617058      5.142247
# 2   102      nonlearned       3.692033      3.399781      4.234698
# 3   510  LearnedPriorLR       1.039794      0.954978      1.143384
# 4   510         adapted       0.995870      0.958409      1.026916
# 5   510      nonlearned       1.004815      0.961376      1.051639
# 6  1020  LearnedPriorLR       0.543754      0.520431      0.579333
# 7  1020         adapted       0.577917      0.571242      0.586185
# 8  1020      nonlearned       0.591560      0.580703      0.608089
