# %%
import sys
sys.path.append('../src/')

# %load_ext autoreload
# %autoreload 2
# Importing our custom module(s)
import losses
import utils

# %%
import os
import itertools
import re
import numpy as np
import pandas as pd
# PyTorch
import torch

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/FGVCAircraft'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [100, 500, 1000, 5000]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'nonlearned'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_FGVC-Aircraft'
weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
count = -1
for lr_0, n, random_state, weight_decay in itertools.product(lr_0s, ns, random_states, weight_decays):
    count += 1
    model_name = f'{prior_type}_lr_0={lr_0}_n={n}_random_state={random_state}_weight_decay={weight_decay}'
    print(f'    "python ../src/main_FGVC-Aircraft.py --bb_weight_decay={weight_decay} --clf_weight_decay={weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --random_state={random_state} --tune --wandb --wandb_project=\'{wandb_project}\'"')
print(count)
# Out:
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='nonlearned_lr_0=0.1_n=100_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='nonlearned_lr_0=0.1_n=500_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='nonlearned_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='nonlearned_lr_0=0.1_n=5000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='nonlearned_lr_0=0.01_n=100_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=500 --model_name='nonlearned_lr_0=0.01_n=500_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=500 --model_name='nonlearned_lr_0=0.01_n=500_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=500 --model_name='nonlearned_lr_0=0.01_n=500_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=500 --model_name='nonlearned_lr_0=0.01_n=500_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=500 --model_name='nonlearned_lr_0=0.01_n=500_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
# ...
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='nonlearned_lr_0=0.0001_n=1000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='nonlearned_lr_0=0.0001_n=1000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='nonlearned_lr_0=0.0001_n=1000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='nonlearned_lr_0=0.0001_n=1000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='nonlearned_lr_0=0.0001_n=1000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='nonlearned_lr_0=0.0001_n=1000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='nonlearned_lr_0=0.0001_n=1000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='nonlearned_lr_0=0.0001_n=1000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='nonlearned_lr_0=0.0001_n=1000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='nonlearned_lr_0=0.0001_n=1000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='nonlearned_lr_0=0.0001_n=1000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='nonlearned_lr_0=0.0001_n=1000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='nonlearned_lr_0=0.0001_n=1000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='nonlearned_lr_0=0.0001_n=5000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
# 287

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/FGVCAircraft'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [100, 500, 1000, 5000]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'adapted'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_FGVC-Aircraft'
weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
count = -1
for lr_0, n, random_state, weight_decay in itertools.product(lr_0s, ns, random_states, weight_decays):
    count += 1
    model_name = f'{prior_type}_lr_0={lr_0}_n={n}_random_state={random_state}_weight_decay={weight_decay}'
    print(f'    "python ../src/main_FGVC-Aircraft.py --bb_weight_decay={weight_decay} --clf_weight_decay={weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune --wandb --wandb_project=\'{wandb_project}\'"')
print(count)
# Out:
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='adapted_lr_0=0.1_n=100_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=500 --model_name='adapted_lr_0=0.1_n=500_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=1000 --model_name='adapted_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=5000 --model_name='adapted_lr_0=0.1_n=5000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='adapted_lr_0=0.01_n=100_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=500 --model_name='adapted_lr_0=0.01_n=500_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
# ...
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='adapted_lr_0=0.0001_n=1000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='adapted_lr_0=0.0001_n=1000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='adapted_lr_0=0.0001_n=1000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='adapted_lr_0=0.0001_n=1000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='adapted_lr_0=0.0001_n=1000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='adapted_lr_0=0.0001_n=1000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='adapted_lr_0=0.0001_n=1000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='adapted_lr_0=0.0001_n=1000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='adapted_lr_0=0.0001_n=1000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='adapted_lr_0=0.0001_n=1000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='adapted_lr_0=0.0001_n=1000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=1000 --model_name='adapted_lr_0=0.0001_n=1000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=5000 --model_name='adapted_lr_0=0.0001_n=5000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='adapted' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
# 287

# %%
bb_weight_decays = np.logspace(0, 9, num=10)
clf_weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
dataset_path = '/cluster/tufts/hugheslab/eharve06/FGVCAircraft'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [100]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'LearnedPriorLR'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_FGVC-Aircraft'
count = -1
for bb_weight_decay, clf_weight_decay, lr_0, n, random_state in itertools.product(bb_weight_decays, clf_weight_decays, lr_0s, ns, random_states):
    count += 1
    model_name = f'{prior_type}_bb_weight_decay={bb_weight_decay}_clf_weight_decay={clf_weight_decay}_lr_0={lr_0}_n={n}_random_state={random_state}'
    print(f'    "python ../src/main_FGVC-Aircraft.py --bb_weight_decay={bb_weight_decay} --clf_weight_decay={clf_weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune --wandb --wandb_project=\'{wandb_project}\'"')
print(count)
# Out:
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.1_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.1_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.1_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.01_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.01_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.01_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.0001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.0001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.0001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.1_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.1_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.1_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.01_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.01_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.01_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.0001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.0001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.0001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.1_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.1_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.1_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.01_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.01_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.01_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.0001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.0001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.0001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.1_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.1_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.1_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.01_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.01_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.01_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.0001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.0001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.0001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.1_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.1_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.1_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.01_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.01_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.01_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.0001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.0001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.0001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.1_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.1_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.1_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.01_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.01_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.01_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.0001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.0001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.0001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.1_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.1_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.1_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.01_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.01_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.01_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.0001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.0001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.0001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=10.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.001_lr_0=0.1_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
# ...
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-05_lr_0=0.0001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-05_lr_0=0.0001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-05_lr_0=0.0001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.1_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.1_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.1_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.01_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.01_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.01_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.0001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.0001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.0001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.1_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.1_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.1 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.1_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.01_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.01_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.01 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.01_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.0001_n=100_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.0001_n=100_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
#     "python ../src/main_FGVC-Aircraft.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/FGVCAircraft' --experiments_path='/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft' --lr_0=0.0001 --n=100 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.0001_n=100_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_FGVC-Aircraft'"
# 719

# %%
def get_df(path):
    df = pd.read_csv(path, index_col='Unnamed: 0')
    return df

def get_val_nll(df):
    return df.val_or_test_nll.values[-1]

def get_val_acc1(df):
    if 'val_or_test_acc' in df.columns:
        return df.val_or_test_acc.values[-1]
    elif 'val_or_test_acc1' in df.columns:
        return df.val_or_test_acc1.values[-1]

# %%
def get_best_hyperparams(
    bb_weight_decays, 
    clf_weight_decays, 
    experiments_path, # Gets best hyperparameters from experiments_path
    lr_0s, 
    ns, 
    prior_type, # Gets best hyperparameters for a single prior_type
    random_states, 
    weight_decays
):
    hyperparam_names = ['bb_weight_decay', 'clf_weight_decay', 'lr_0', 'n', 'random_state', 'weight_decay']
    columns = ['model_name', 'n', 'prior_type', 'random_state', 'val_acc1', 'val_nll']
    df = pd.DataFrame(columns=columns)
    
    for hyperparams in itertools.product(bb_weight_decays, clf_weight_decays, lr_0s, ns, random_states, weight_decays):
        model_name = f'{prior_type}_' + '_'.join(f'{hyperparam_name}={hyperparam}' for hyperparam_name, hyperparam in zip(hyperparam_names, hyperparams) if hyperparam is not None)
        bb_weight_decay, clf_weight_decay, lr_0, n, random_state, weight_decay = hyperparams
        if not os.path.exists(f'{experiments_path}/{model_name}.csv'):
            print(model_name)
            pass
        else:
            temp_df = get_df(f'{experiments_path}/{model_name}.csv')
            val_acc1 = get_val_acc1(temp_df)
            val_nll = get_val_nll(temp_df)
            df.loc[df.shape[0]] = [model_name, n, prior_type, random_state, val_acc1, val_nll]
                    
    min_indices = df.groupby(['n', 'random_state'])['val_nll'].idxmin()
    df = df.loc[min_indices].reset_index(drop=True)
    #max_indices = df.groupby(['n', 'random_state'])['val_acc1'].idxmax()
    #df = df.loc[max_indices].reset_index(drop=True)
                    
    return df
                    
def get_results(
    df,
    experiments_path
):
    columns = ['model_name', 'n', 'prior_type', 'random_state', 'test_acc1', 'test_nll']
    results_df = pd.DataFrame(columns=columns)
    
    for row_index, row in df.iterrows():
        model_name = row.model_name
        prior_type, n, random_state = row.prior_type, row.n, row.random_state
        if not os.path.exists(f'{experiments_path}/{model_name}.csv'):
            #print(model_name)
            pass
        else:
            temp_df = get_df(f'{experiments_path}/{model_name}.csv')
            test_acc1 = get_val_acc1(temp_df)
            test_nll = get_val_nll(temp_df)
            condition = (results_df['n']==n)&(results_df['random_state']==random_state)
            if len(results_df[condition]) == 0:
                results_df.loc[results_df.shape[0]] = [model_name, n, prior_type, random_state, test_acc1, test_nll]
    
    return results_df

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/FGVCAircraft'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [100, 500, 1000, 5000]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'nonlearned'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_FGVC-Aircraft'
weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]

std_prior = get_best_hyperparams([None], [None], experiments_path, lr_0s, ns, prior_type, random_states, weight_decays)
std_prior
# Out:
#                                            model_name     n  prior_type  \
# 0   nonlearned_lr_0=0.01_n=100_random_state=1001_w...   100  nonlearned
# 1   nonlearned_lr_0=0.01_n=100_random_state=2001_w...   100  nonlearned
# 2   nonlearned_lr_0=0.001_n=100_random_state=3001_...   100  nonlearned
# 3   nonlearned_lr_0=0.001_n=500_random_state=1001_...   500  nonlearned
# 4   nonlearned_lr_0=0.001_n=500_random_state=2001_...   500  nonlearned
# 5   nonlearned_lr_0=0.001_n=500_random_state=3001_...   500  nonlearned
# 6   nonlearned_lr_0=0.001_n=1000_random_state=1001...  1000  nonlearned
# 7   nonlearned_lr_0=0.001_n=1000_random_state=2001...  1000  nonlearned
# 8   nonlearned_lr_0=0.001_n=1000_random_state=3001...  1000  nonlearned
# 9   nonlearned_lr_0=0.01_n=5000_random_state=1001_...  5000  nonlearned
# 10  nonlearned_lr_0=0.01_n=5000_random_state=2001_...  5000  nonlearned
# 11  nonlearned_lr_0=0.01_n=5000_random_state=3001_...  5000  nonlearned
#
#     random_state  val_acc1   val_nll
# 0           1001     0.000  4.965381
# 1           2001     0.000  4.894990
# 2           3001     0.000  5.305157
# 3           1001     0.170  4.009337
# 4           2001     0.180  3.650569
# 5           3001     0.190  3.823918
# 6           1001     0.360  2.856592
# 7           2001     0.380  2.644632
# 8           3001     0.415  2.406847
# 9           1001     0.852  0.683940
# 10          2001     0.824  0.735676
# 11          3001     0.835  0.719795

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/FGVCAircraft'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/retrained_FGVC-Aircraft'
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
wandb_project = 'retrained_FGVC-Aircraft'

pattern = re.compile(r'(\w+)_lr_0=([\d.]+)_n=(\d+)_random_state=(\d+)_weight_decay=([\d.]+(?:e[-+]?\d+)?)')
for row_index, row in std_prior.iterrows():
    model_name = row.model_name
    match = pattern.match(model_name)
    prior_type, lr_0, n, random_state, weight_decay = match.groups()
    if not os.path.exists(f'{experiments_path}/{model_name}.csv'):
        print(f'    "python ../src/main_FGVCAircraft.py --bb_weight_decay={weight_decay} --clf_weight_decay={weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save --wandb --wandb_project=\'{wandb_project}\'"')

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/FGVCAircraft'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [100, 500, 1000, 5000]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'adapted'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_FGVC-Aircraft'
weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]

learned_prior_iso = get_best_hyperparams([None], [None], experiments_path, lr_0s, ns, prior_type, random_states, weight_decays)
learned_prior_iso
# Out:
#                                            model_name     n prior_type  \
# 0   adapted_lr_0=0.01_n=100_random_state=1001_weig...   100    adapted
# 1   adapted_lr_0=0.01_n=100_random_state=2001_weig...   100    adapted
# 2   adapted_lr_0=0.01_n=100_random_state=3001_weig...   100    adapted
# 3   adapted_lr_0=0.1_n=500_random_state=1001_weigh...   500    adapted
# 4   adapted_lr_0=0.1_n=500_random_state=2001_weigh...   500    adapted
# 5   adapted_lr_0=0.1_n=500_random_state=3001_weigh...   500    adapted
# 6   adapted_lr_0=0.1_n=1000_random_state=1001_weig...  1000    adapted
# 7   adapted_lr_0=0.1_n=1000_random_state=2001_weig...  1000    adapted
# 8   adapted_lr_0=0.1_n=1000_random_state=3001_weig...  1000    adapted
# 9   adapted_lr_0=0.1_n=5000_random_state=1001_weig...  5000    adapted
# 10  adapted_lr_0=0.1_n=5000_random_state=2001_weig...  5000    adapted
# 11  adapted_lr_0=0.1_n=5000_random_state=3001_weig...  5000    adapted
#
#     random_state  val_acc1   val_nll
# 0           1001     0.000  4.843275
# 1           2001     0.000  4.727925
# 2           3001     0.000  4.894067
# 3           1001     0.150  3.978456
# 4           2001     0.210  3.542619
# 5           3001     0.130  3.744623
# 6           1001     0.375  2.538885
# 7           2001     0.440  2.395383
# 8           3001     0.485  2.251683
# 9           1001     0.831  0.659857
# 10          2001     0.826  0.661257
# 11          3001     0.827  0.662595

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/FGVCAircraft'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/retrained_FGVC-Aircraft'
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
wandb_project = 'retrained_FGVC-Aircraft'

pattern = re.compile(r'(\w+)_lr_0=([\d.]+)_n=(\d+)_random_state=(\d+)_weight_decay=([\d.]+(?:e[-+]?\d+)?)')
for row_index, row in learned_prior_iso.iterrows():
    model_name = row.model_name
    match = pattern.match(model_name)
    prior_type, lr_0, n, random_state, weight_decay = match.groups()
    if not os.path.exists(f'{experiments_path}/{model_name}.csv'):
        print(f'    "python ../src/main_FGVCAircraft.py --bb_weight_decay={weight_decay} --clf_weight_decay={weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save --wandb --wandb_project=\'{wandb_project}\'"')

# %%
bb_weight_decays = np.logspace(0, 9, num=10)
clf_weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
dataset_path = '/cluster/tufts/hugheslab/eharve06/FGVCAircraft'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_FGVC-Aircraft'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [100, 5000]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'LearnedPriorLR'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_FGVC-Aircraft'
weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]

learned_prior_lr = get_best_hyperparams(bb_weight_decays, clf_weight_decays, experiments_path, lr_0s, ns, prior_type, random_states, [None])
learned_prior_lr
# Out:
#                                           model_name     n      prior_type  \
# 0  LearnedPriorLR_bb_weight_decay=1000000000.0_cl...   100  LearnedPriorLR
# 1  LearnedPriorLR_bb_weight_decay=100000.0_clf_we...   100  LearnedPriorLR
# 2  LearnedPriorLR_bb_weight_decay=100000000.0_clf...   100  LearnedPriorLR
# 3  LearnedPriorLR_bb_weight_decay=100000.0_clf_we...  5000  LearnedPriorLR
# 4  LearnedPriorLR_bb_weight_decay=100.0_clf_weigh...  5000  LearnedPriorLR
# 5  LearnedPriorLR_bb_weight_decay=10.0_clf_weight...  5000  LearnedPriorLR
#
#    random_state  val_acc1   val_nll
# 0          1001     0.000  4.797351
# 1          2001     0.000  4.735919
# 2          3001     0.000  4.916016
# 3          1001     0.836  0.688586
# 4          2001     0.819  0.725457
# 5          3001     0.826  0.733401

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/FGVCAircraft'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/retrained_FGVC-Aircraft'
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
wandb_project = 'retrained_FGVC-Aircraft'

pattern = re.compile(r'(\w+)_bb_weight_decay=([\d.]+)_clf_weight_decay=([\d.]+(?:e[-+]?\d+)?)_lr_0=([\d.]+)_n=(\d+)_random_state=(\d+)')
for row_index, row in learned_prior_lr.iterrows():
    model_name = row.model_name
    match = pattern.match(model_name)
    prior_type, bb_weight_decay, clf_weight_decay, lr_0, n, random_state = match.groups()
    if not os.path.exists(f'{experiments_path}/{model_name}.csv'):
        print(f'    "python ../src/main_FGVCAircraft.py --bb_weight_decay={bb_weight_decay} --clf_weight_decay={clf_weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save --wandb --wandb_project=\'{wandb_project}\'"')

# %%
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/retrained_FGVC-Aircraft'
std_prior_results = get_results(std_prior, experiments_path)
learned_prior_iso_results = get_results(learned_prior_iso, experiments_path)
learned_prior_lr_results = get_results(learned_prior_lr, experiments_path)
results = pd.concat([std_prior_results, learned_prior_iso_results, learned_prior_lr_results])
results
# Out:
#                                            model_name     n      prior_type  \
# 0   nonlearned_lr_0=0.01_n=100_random_state=1001_w...   100      nonlearned
# 1   nonlearned_lr_0=0.01_n=100_random_state=2001_w...   100      nonlearned
# 2   nonlearned_lr_0=0.001_n=100_random_state=3001_...   100      nonlearned
# 3   nonlearned_lr_0=0.001_n=500_random_state=1001_...   500      nonlearned
# 4   nonlearned_lr_0=0.001_n=500_random_state=2001_...   500      nonlearned
# 5   nonlearned_lr_0=0.001_n=500_random_state=3001_...   500      nonlearned
# 6   nonlearned_lr_0=0.001_n=1000_random_state=1001...  1000      nonlearned
# 7   nonlearned_lr_0=0.001_n=1000_random_state=2001...  1000      nonlearned
# 8   nonlearned_lr_0=0.001_n=1000_random_state=3001...  1000      nonlearned
# 9   nonlearned_lr_0=0.01_n=5000_random_state=1001_...  5000      nonlearned
# 10  nonlearned_lr_0=0.01_n=5000_random_state=2001_...  5000      nonlearned
# 11  nonlearned_lr_0=0.01_n=5000_random_state=3001_...  5000      nonlearned
# 0   adapted_lr_0=0.01_n=100_random_state=1001_weig...   100         adapted
# 1   adapted_lr_0=0.01_n=100_random_state=2001_weig...   100         adapted
# 2   adapted_lr_0=0.01_n=100_random_state=3001_weig...   100         adapted
# 3   adapted_lr_0=0.1_n=500_random_state=1001_weigh...   500         adapted
# 4   adapted_lr_0=0.1_n=500_random_state=2001_weigh...   500         adapted
# 5   adapted_lr_0=0.1_n=500_random_state=3001_weigh...   500         adapted
# 6   adapted_lr_0=0.1_n=1000_random_state=1001_weig...  1000         adapted
# 7   adapted_lr_0=0.1_n=1000_random_state=2001_weig...  1000         adapted
# 8   adapted_lr_0=0.1_n=1000_random_state=3001_weig...  1000         adapted
# 9   adapted_lr_0=0.1_n=5000_random_state=1001_weig...  5000         adapted
# 10  adapted_lr_0=0.1_n=5000_random_state=2001_weig...  5000         adapted
# 11  adapted_lr_0=0.1_n=5000_random_state=3001_weig...  5000         adapted
# 0   LearnedPriorLR_bb_weight_decay=1000000000.0_cl...   100  LearnedPriorLR
# 1   LearnedPriorLR_bb_weight_decay=100000.0_clf_we...   100  LearnedPriorLR
# 2   LearnedPriorLR_bb_weight_decay=100000000.0_clf...   100  LearnedPriorLR
# 3   LearnedPriorLR_bb_weight_decay=100000.0_clf_we...  5000  LearnedPriorLR
# 4   LearnedPriorLR_bb_weight_decay=100.0_clf_weigh...  5000  LearnedPriorLR
# 5   LearnedPriorLR_bb_weight_decay=10.0_clf_weight...  5000  LearnedPriorLR
#
#     random_state  test_acc1  test_nll
# 0           1001   0.017701  4.747743
# 1           2001   0.012950  5.177504
# 2           3001   0.046096  4.713797
# 3           1001   0.215713  3.566221
# 4           2001   0.214305  3.554496
# 5           3001   0.243939  3.425823
# 6           1001   0.417656  2.398558
# 7           2001   0.398155  2.497329
# 8           3001   0.401604  2.493966
# 9           1001   0.856203  0.615359
# 10          2001   0.854331  0.613668
# 11          3001   0.860107  0.600848
# 0           1001   0.028164  4.655359
# 1           2001   0.032620  4.667740
# 2           3001   0.045446  4.683396
# 3           1001   0.263378  3.261761
# 4           2001   0.240258  3.628757
# 5           3001   0.272576  3.228630
# 6           1001   0.500401  2.051523
# 7           2001   0.513859  2.043088
# 8           3001   0.525562  1.943772
# 9           1001   0.859456  0.563375
# 10          2001   0.859171  0.567034
# 11          3001   0.857995  0.569945
# 0           1001   0.035330  4.667678
# 1           2001   0.035312  4.655238
# 2           3001   0.041943  4.712551
# 3           1001   0.834777  0.665908
# 4           2001   0.852611  0.603560
# 5           3001   0.837540  0.659248

# %%
grouped_results = results.groupby(['n', 'prior_type']).agg(lambda x: tuple(x))
columns = ['test_acc1', 'test_nll']
for column in columns:
    grouped_results[f'{column}_mean'] = grouped_results[column].apply(lambda item: np.mean(item))
    grouped_results[f'{column}_std'] = grouped_results[column].apply(lambda item: np.std(item))
    grouped_results[f'{column}_min'] = grouped_results[column].apply(lambda item: np.min(item))
    grouped_results[f'{column}_max'] = grouped_results[column].apply(lambda item: np.max(item))
grouped_results = grouped_results.reset_index()
grouped_results
# Out:
#       n      prior_type                                         model_name  \
# 0   100  LearnedPriorLR  (LearnedPriorLR_bb_weight_decay=1000000000.0_c...
# 1   100         adapted  (adapted_lr_0=0.01_n=100_random_state=1001_wei...
# 2   100      nonlearned  (nonlearned_lr_0=0.01_n=100_random_state=1001_...
# 3   500         adapted  (adapted_lr_0=0.1_n=500_random_state=1001_weig...
# 4   500      nonlearned  (nonlearned_lr_0=0.001_n=500_random_state=1001...
# 5  1000         adapted  (adapted_lr_0=0.1_n=1000_random_state=1001_wei...
# 6  1000      nonlearned  (nonlearned_lr_0=0.001_n=1000_random_state=100...
# 7  5000  LearnedPriorLR  (LearnedPriorLR_bb_weight_decay=100000.0_clf_w...
# 8  5000         adapted  (adapted_lr_0=0.1_n=5000_random_state=1001_wei...
# 9  5000      nonlearned  (nonlearned_lr_0=0.01_n=5000_random_state=1001...
#
#          random_state                                          test_acc1  \
# 0  (1001, 2001, 3001)  (0.035329770296812, 0.0353119447827339, 0.0419...
# 1  (1001, 2001, 3001)  (0.0281639918684959, 0.0326203219592571, 0.045...
# 2  (1001, 2001, 3001)  (0.0177005361765623, 0.0129500888288021, 0.046...
# 3  (1001, 2001, 3001)  (0.2633779048919678, 0.2402584701776504, 0.272...
# 4  (1001, 2001, 3001)  (0.2157130241394043, 0.2143048048019409, 0.243...
# 5  (1001, 2001, 3001)  (0.5004010796546936, 0.513859212398529, 0.5255...
# 6  (1001, 2001, 3001)  (0.4176559746265411, 0.3981550931930542, 0.401...
# 7  (1001, 2001, 3001)  (0.8347771167755127, 0.8526114225387573, 0.837...
# 8  (1001, 2001, 3001)  (0.8594563603401184, 0.8591711521148682, 0.857...
# 9  (1001, 2001, 3001)  (0.8562031984329224, 0.8543314933776855, 0.860...
#
#                                             test_nll  test_acc1_mean  \
# 0  (4.667678046577013, 4.655237975293654, 4.71255...        0.037528
# 1  (4.655358526251033, 4.667739737402237, 4.68339...        0.035410
# 2  (4.747742966635608, 5.177504366094416, 4.71379...        0.025582
# 3  (3.2617605282600093, 3.6287569623432674, 3.228...        0.258737
# 4  (3.5662205908128954, 3.554496137937768, 3.4258...        0.224652
# 5  (2.051522671765048, 2.04308819770813, 1.943771...        0.513274
# 6  (2.398557525978694, 2.4973293598299806, 2.4939...        0.405805
# 7  (0.6659078285424446, 0.6035599237692955, 0.659...        0.841643
# 8  (0.5633753695682546, 0.5670339276831394, 0.569...        0.858874
# 9  (0.6153585004566885, 0.6136678567062868, 0.600...        0.856881
#
#    test_acc1_std  test_acc1_min  test_acc1_max  test_nll_mean  test_nll_std  \
# 0       0.003122       0.035312       0.041943       4.678489      0.024615
# 1       0.007326       0.028164       0.045446       4.668831      0.011472
# 2       0.014635       0.012950       0.046096       4.879681      0.211048
# 3       0.013595       0.240258       0.272576       3.373049      0.181318
# 4       0.013650       0.214305       0.243939       3.515513      0.063601
# 5       0.010280       0.500401       0.525562       2.012794      0.048927
# 6       0.008497       0.398155       0.417656       2.463284      0.045789
# 7       0.007838       0.834777       0.852611       0.642905      0.027954
# 8       0.000633       0.857995       0.859456       0.566785      0.002688
# 9       0.002406       0.854331       0.860107       0.609958      0.006479
#
#    test_nll_min  test_nll_max
# 0      4.655238      4.712551
# 1      4.655359      4.683396
# 2      4.713797      5.177504
# 3      3.228630      3.628757
# 4      3.425823      3.566221
# 5      1.943772      2.051523
# 6      2.398558      2.497329
# 7      0.603560      0.665908
# 8      0.563375      0.569945
# 9      0.600848      0.615359

# %%
grouped_results[['n', 'prior_type', 'test_acc1_mean', 'test_acc1_min', 'test_acc1_max']]
# Out:
#       n      prior_type  test_acc1_mean  test_acc1_min  test_acc1_max
# 0   100  LearnedPriorLR        0.037528       0.035312       0.041943
# 1   100         adapted        0.035410       0.028164       0.045446
# 2   100      nonlearned        0.025582       0.012950       0.046096
# 3   500         adapted        0.258737       0.240258       0.272576
# 4   500      nonlearned        0.224652       0.214305       0.243939
# 5  1000         adapted        0.513274       0.500401       0.525562
# 6  1000      nonlearned        0.405805       0.398155       0.417656
# 7  5000  LearnedPriorLR        0.841643       0.834777       0.852611
# 8  5000         adapted        0.858874       0.857995       0.859456
# 9  5000      nonlearned        0.856881       0.854331       0.860107

# %%
grouped_results[['n', 'prior_type', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#       n      prior_type  test_nll_mean  test_nll_min  test_nll_max
# 0   100  LearnedPriorLR       4.678489      4.655238      4.712551
# 1   100         adapted       4.668831      4.655359      4.683396
# 2   100      nonlearned       4.879681      4.713797      5.177504
# 3   500         adapted       3.373049      3.228630      3.628757
# 4   500      nonlearned       3.515513      3.425823      3.566221
# 5  1000         adapted       2.012794      1.943772      2.051523
# 6  1000      nonlearned       2.463284      2.398558      2.497329
# 7  5000  LearnedPriorLR       0.642905      0.603560      0.665908
# 8  5000         adapted       0.566785      0.563375      0.569945
# 9  5000      nonlearned       0.609958      0.600848      0.615359
