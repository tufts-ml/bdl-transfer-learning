# %%
import sys
sys.path.append('../src/')

# %load_ext autoreload
# %autoreload 2
# Importing our custom module(s)
import losses
import utils

# %%
import os
import itertools
import re
import numpy as np
import pandas as pd
# PyTorch
import torch

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets'
experiments_path = '/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [10, 100, 1000, 10000, 50000]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'StdPrior'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_Oxford-IIIT_Pets'
weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
count = -1
for lr_0, n, random_state, weight_decay in itertools.product(lr_0s, ns, random_states, weight_decays):
    count += 1
    model_name = f'{prior_type}_lr_0={lr_0}_n={n}_random_state={random_state}_weight_decay={weight_decay}'
    print(f'    "python ../src/main_OXPETS.py --bb_weight_decay={weight_decay} --clf_weight_decay={weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --random_state={random_state} --tune --wandb --wandb_project=\'{wandb_project}\'"')
print(count)
# Out:
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='StdPrior_lr_0=0.1_n=10_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='StdPrior_lr_0=0.1_n=100_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='StdPrior_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='StdPrior_lr_0=0.1_n=10000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='StdPrior_lr_0=0.1_n=50000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=10 --model_name='StdPrior_lr_0=0.01_n=10_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=10 --model_name='StdPrior_lr_0=0.01_n=10_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=10 --model_name='StdPrior_lr_0=0.01_n=10_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=10 --model_name='StdPrior_lr_0=0.01_n=10_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=10 --model_name='StdPrior_lr_0=0.01_n=10_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=10 --model_name='StdPrior_lr_0=0.01_n=10_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=10 --model_name='StdPrior_lr_0=0.01_n=10_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
# ...
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='StdPrior_lr_0=0.0001_n=10000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='StdPrior_lr_0=0.0001_n=10000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='StdPrior_lr_0=0.0001_n=10000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='StdPrior_lr_0=0.0001_n=10000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='StdPrior_lr_0=0.0001_n=10000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='StdPrior_lr_0=0.0001_n=10000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='StdPrior_lr_0=0.0001_n=10000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='StdPrior_lr_0=0.0001_n=10000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='StdPrior_lr_0=0.0001_n=10000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='StdPrior_lr_0=0.0001_n=10000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='StdPrior_lr_0=0.0001_n=10000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='StdPrior_lr_0=0.0001_n=10000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='StdPrior_lr_0=0.0001_n=10000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='StdPrior_lr_0=0.0001_n=50000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
# 359

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets'
experiments_path = '/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [10, 100, 1000, 10000, 50000]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'LearnedPriorIso'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_Oxford-IIIT_Pets'
weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
count = -1
for lr_0, n, random_state, weight_decay in itertools.product(lr_0s, ns, random_states, weight_decays):
    count += 1
    model_name = f'{prior_type}_lr_0={lr_0}_n={n}_random_state={random_state}_weight_decay={weight_decay}'
    print(f'    "python ../src/main_OXPETS.py --bb_weight_decay={weight_decay} --clf_weight_decay={weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune --wandb --wandb_project=\'{wandb_project}\'"')
print(count)
# Out:
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10 --model_name='LearnedPriorIso_lr_0=0.1_n=10_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=100 --model_name='LearnedPriorIso_lr_0=0.1_n=100_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=1000 --model_name='LearnedPriorIso_lr_0=0.1_n=1000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=10000 --model_name='LearnedPriorIso_lr_0=0.1_n=10000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=50000 --model_name='LearnedPriorIso_lr_0=0.1_n=50000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
# ...
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='LearnedPriorIso_lr_0=0.0001_n=10000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='LearnedPriorIso_lr_0=0.0001_n=10000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='LearnedPriorIso_lr_0=0.0001_n=10000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='LearnedPriorIso_lr_0=0.0001_n=10000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='LearnedPriorIso_lr_0=0.0001_n=10000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='LearnedPriorIso_lr_0=0.0001_n=10000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='LearnedPriorIso_lr_0=0.0001_n=10000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='LearnedPriorIso_lr_0=0.0001_n=10000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='LearnedPriorIso_lr_0=0.0001_n=10000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='LearnedPriorIso_lr_0=0.0001_n=10000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=10000 --model_name='LearnedPriorIso_lr_0=0.0001_n=10000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=1001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=1001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=1001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=1001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=1001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=1001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=2001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=2001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=2001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=2001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=2001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=2001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.01 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=3001_weight_decay=0.01' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.001 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=3001_weight_decay=0.001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0001 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=3001_weight_decay=0.0001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-05 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=3001_weight_decay=1e-05' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1e-06 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=3001_weight_decay=1e-06' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=0.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=50000 --model_name='LearnedPriorIso_lr_0=0.0001_n=50000_random_state=3001_weight_decay=0.0' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorIso' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
# 359

# %%
bb_weight_decays = np.logspace(0, 9, num=10)
clf_weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets'
experiments_path = '/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [3441]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'LearnedPriorLR'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_Oxford-IIIT_Pets'
count = -1
for bb_weight_decay, clf_weight_decay, lr_0, n, random_state in itertools.product(bb_weight_decays, clf_weight_decays, lr_0s, ns, random_states):
    count += 1
    model_name = f'{prior_type}_bb_weight_decay={bb_weight_decay}_clf_weight_decay={clf_weight_decay}_lr_0={lr_0}_n={n}_random_state={random_state}'
    print(f'    "python ../src/main_OXPETS.py --bb_weight_decay={bb_weight_decay} --clf_weight_decay={clf_weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune --wandb --wandb_project=\'{wandb_project}\'"')
print(count)
# Out:
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.1_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.1_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.1_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.01_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.01_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.01_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.0001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.0001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.01_lr_0=0.0001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.1_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.1_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.1_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.01_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.01_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.01_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.0001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.0001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.001_lr_0=0.0001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.1_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.1_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.1_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.01_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.01_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.01_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.0001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.0001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0001_lr_0=0.0001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.1_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.1_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.1_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.01_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.01_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.01_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.0001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.0001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-05_lr_0=0.0001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.1_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.1_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.1_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.01_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.01_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.01_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.0001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.0001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=1e-06_lr_0=0.0001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.1_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.1_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.1_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.01_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.01_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.01_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.0001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.0001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1.0_clf_weight_decay=0.0_lr_0=0.0001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.1_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.1_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.1_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.01_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.01_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.01_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.0001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.0001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=10.0 --clf_weight_decay=0.01 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.01_lr_0=0.0001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=10.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.001_lr_0=0.1_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=10.0 --clf_weight_decay=0.001 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=10.0_clf_weight_decay=0.001_lr_0=0.1_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
# ...
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-05_lr_0=0.0001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-05_lr_0=0.0001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-05 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-05_lr_0=0.0001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.1_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.1_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.1_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.01_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.01_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.01_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.0001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.0001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=1e-06 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=1e-06_lr_0=0.0001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.1_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.1_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.1 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.1_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.01_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.01_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.01 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.01_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.0001_n=3441_random_state=1001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=1001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.0001_n=3441_random_state=2001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=2001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
#     "python ../src/main_OXPETS.py --bb_weight_decay=1000000000.0 --clf_weight_decay=0.0 --dataset_path='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets' --experiments_path='/cluster/home/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets' --lr_0=0.0001 --n=3441 --model_name='LearnedPriorLR_bb_weight_decay=1000000000.0_clf_weight_decay=0.0_lr_0=0.0001_n=3441_random_state=3001' --prior_path='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='LearnedPriorLR' --random_state=3001 --tune --wandb --wandb_project='tuned_Oxford-IIIT_Pets'"
# 719

# %%
def get_df(path):
    df = pd.read_csv(path, index_col='Unnamed: 0')
    return df

def get_val_nll(df):
    return df.val_or_test_nll.values[-1]

def get_val_acc1(df):
    if 'val_or_test_acc' in df.columns:
        return df.val_or_test_acc.values[-1] if df.val_or_test_acc.values[-1] < 1.0 else df.val_or_test_acc.values[-1]/100
    elif 'val_or_test_acc1' in df.columns:
        return df.val_or_test_acc1.values[-1] if df.val_or_test_acc1.values[-1] < 1.0 else df.val_or_test_acc1.values[-1]/100

# %%
def get_best_hyperparams(
    bb_weight_decays, 
    clf_weight_decays, 
    experiments_path, # Gets best hyperparameters from experiments_path
    lr_0s, 
    ns, 
    prior_type, # Gets best hyperparameters for a single prior_type
    random_states, 
    weight_decays
):
    hyperparam_names = ['bb_weight_decay', 'clf_weight_decay', 'lr_0', 'n', 'random_state', 'weight_decay']
    columns = ['model_name', 'n', 'prior_type', 'random_state', 'val_acc1', 'val_nll']
    df = pd.DataFrame(columns=columns)
    
    for hyperparams in itertools.product(bb_weight_decays, clf_weight_decays, lr_0s, ns, random_states, weight_decays):
        model_name = f'{prior_type}_' + '_'.join(f'{hyperparam_name}={hyperparam}' for hyperparam_name, hyperparam in zip(hyperparam_names, hyperparams) if hyperparam is not None)
        bb_weight_decay, clf_weight_decay, lr_0, n, random_state, weight_decay = hyperparams
        if not os.path.exists(f'{experiments_path}/{model_name}.csv'):
            print(model_name)
            pass
        else:
            temp_df = get_df(f'{experiments_path}/{model_name}.csv')
            val_acc1 = get_val_acc1(temp_df)
            val_nll = get_val_nll(temp_df)
            df.loc[df.shape[0]] = [model_name, n, prior_type, random_state, val_acc1, val_nll]
                    
    min_indices = df.groupby(['n', 'random_state'])['val_nll'].idxmin()
    df = df.loc[min_indices].reset_index(drop=True)
    #max_indices = df.groupby(['n', 'random_state'])['val_acc1'].idxmax()
    #df = df.loc[max_indices].reset_index(drop=True)
                    
    return df
                    
def get_results(
    df,
    experiments_path
):
    columns = ['model_name', 'n', 'prior_type', 'random_state', 'test_acc1', 'test_nll']
    results_df = pd.DataFrame(columns=columns)
    
    for row_index, row in df.iterrows():
        model_name = row.model_name
        prior_type, n, random_state = row.prior_type, row.n, row.random_state
        if not os.path.exists(f'{experiments_path}/{model_name}.csv'):
            #print(model_name)
            pass
        else:
            temp_df = get_df(f'{experiments_path}/{model_name}.csv')
            test_acc1 = get_val_acc1(temp_df)
            test_nll = get_val_nll(temp_df)
            condition = (results_df['n']==n)&(results_df['random_state']==random_state)
            if len(results_df[condition]) == 0:
                results_df.loc[results_df.shape[0]] = [model_name, n, prior_type, random_state, test_acc1, test_nll]
    
    return results_df

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [37, 370, 3441]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'nonlearned'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_Oxford-IIIT_Pets'
weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]

std_prior = get_best_hyperparams([None], [None], experiments_path, lr_0s, ns, prior_type, random_states, weight_decays)
std_prior
# Out:
#                                           model_name     n  prior_type  \
# 0  nonlearned_lr_0=0.001_n=37_random_state=1001_w...    37  nonlearned
# 1  nonlearned_lr_0=0.001_n=37_random_state=2001_w...    37  nonlearned
# 2  nonlearned_lr_0=0.001_n=37_random_state=3001_w...    37  nonlearned
# 3  nonlearned_lr_0=0.01_n=370_random_state=1001_w...   370  nonlearned
# 4  nonlearned_lr_0=0.001_n=370_random_state=2001_...   370  nonlearned
# 5  nonlearned_lr_0=0.0001_n=370_random_state=3001...   370  nonlearned
# 6  nonlearned_lr_0=0.01_n=3441_random_state=1001_...  3441  nonlearned
# 7  nonlearned_lr_0=0.01_n=3441_random_state=2001_...  3441  nonlearned
# 8  nonlearned_lr_0=0.01_n=3441_random_state=3001_...  3441  nonlearned
#
#    random_state  val_acc1   val_nll
# 0          1001  0.135135  1.126119
# 1          2001  0.135135  1.132164
# 2          3001  0.162162  0.577719
# 3          1001  0.689189  0.966183
# 4          2001  0.635135  1.484370
# 5          3001  0.554054  1.496751
# 6          1001  0.897898  0.378248
# 7          2001  0.897898  0.374211
# 8          3001  0.911411  0.387041

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/retrained_Oxford-IIIT_Pets'
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
wandb_project = 'retrained_Oxford-IIIT_Pets'

pattern = re.compile(r'(\w+)_lr_0=([\d.]+)_n=(\d+)_random_state=(\d+)_weight_decay=([\d.]+(?:e[-+]?\d+)?)')
for row_index, row in std_prior.iterrows():
    model_name = row.model_name
    match = pattern.match(model_name)
    prior_type, lr_0, n, random_state, weight_decay = match.groups()
    if not os.path.exists(f'{experiments_path}/{model_name}.csv'):
        print(f'    "python ../src/main_OXPETS.py --bb_weight_decay={weight_decay} --clf_weight_decay={weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save --wandb --wandb_project=\'{wandb_project}\'"')

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [37, 370, 3441]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'adapted'
random_states = [1001, 2001, 3001]
wandb_project = 'tuned_Oxford-IIIT_Pets'
weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]

learned_prior_iso = get_best_hyperparams([None], [None], experiments_path, lr_0s, ns, prior_type, random_states, weight_decays)
learned_prior_iso
# Out:
#                                           model_name     n prior_type  \
# 0  adapted_lr_0=0.1_n=37_random_state=1001_weight...    37    adapted
# 1  adapted_lr_0=0.1_n=37_random_state=2001_weight...    37    adapted
# 2  adapted_lr_0=0.1_n=37_random_state=3001_weight...    37    adapted
# 3  adapted_lr_0=0.01_n=370_random_state=1001_weig...   370    adapted
# 4  adapted_lr_0=0.01_n=370_random_state=2001_weig...   370    adapted
# 5  adapted_lr_0=0.0001_n=370_random_state=3001_we...   370    adapted
# 6  adapted_lr_0=0.01_n=3441_random_state=1001_wei...  3441    adapted
# 7  adapted_lr_0=0.01_n=3441_random_state=2001_wei...  3441    adapted
# 8  adapted_lr_0=0.01_n=3441_random_state=3001_wei...  3441    adapted
#
#    random_state  val_acc1   val_nll
# 0          1001  0.135135  1.045218
# 1          2001  0.135135  1.057848
# 2          3001  0.162162  0.531087
# 3          1001  0.675676  0.960941
# 4          2001  0.635135  1.453773
# 5          3001  0.540541  1.509936
# 6          1001  0.902402  0.353861
# 7          2001  0.905405  0.355751
# 8          3001  0.923423  0.347386

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/retrained_Oxford-IIIT_Pets'
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
wandb_project = 'retrained_Oxford-IIIT_Pets'

pattern = re.compile(r'(\w+)_lr_0=([\d.]+)_n=(\d+)_random_state=(\d+)_weight_decay=([\d.]+(?:e[-+]?\d+)?)')
for row_index, row in learned_prior_iso.iterrows():
    model_name = row.model_name
    match = pattern.match(model_name)
    prior_type, lr_0, n, random_state, weight_decay = match.groups()
    if not os.path.exists(f'{experiments_path}/{model_name}.csv'):
        print(f'    "python ../src/main_OXPETS.py --bb_weight_decay={weight_decay} --clf_weight_decay={weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save --wandb --wandb_project=\'{wandb_project}\'"')

# %%
bb_weight_decays = np.logspace(0, 9, num=10)
clf_weight_decays = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/tuned_Oxford-IIIT_Pets'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [37, 370, 3441]
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'LearnedPriorLR'
random_states = [1001, 2001, 3001]
wandb_project = 'retrained_Oxford-IIIT_Pets'

learned_prior_lr = get_best_hyperparams(bb_weight_decays, clf_weight_decays, experiments_path, lr_0s, ns, prior_type, random_states, [None])
learned_prior_lr
# Out:
#                                           model_name     n      prior_type  \
# 0  LearnedPriorLR_bb_weight_decay=100000000.0_clf...    37  LearnedPriorLR
# 1  LearnedPriorLR_bb_weight_decay=1000000.0_clf_w...    37  LearnedPriorLR
# 2  LearnedPriorLR_bb_weight_decay=100000000.0_clf...    37  LearnedPriorLR
# 3  LearnedPriorLR_bb_weight_decay=1000000.0_clf_w...   370  LearnedPriorLR
# 4  LearnedPriorLR_bb_weight_decay=10000.0_clf_wei...   370  LearnedPriorLR
# 5  LearnedPriorLR_bb_weight_decay=100.0_clf_weigh...   370  LearnedPriorLR
# 6  LearnedPriorLR_bb_weight_decay=10000.0_clf_wei...  3441  LearnedPriorLR
# 7  LearnedPriorLR_bb_weight_decay=1000.0_clf_weig...  3441  LearnedPriorLR
# 8  LearnedPriorLR_bb_weight_decay=1000.0_clf_weig...  3441  LearnedPriorLR
#
#    random_state  val_acc1   val_nll
# 0          1001  0.750000  0.910380
# 1          2001  0.750000  0.910108
# 2          3001  0.875000  0.457779
# 3          1001  0.716216  0.919932
# 4          2001  0.662162  1.241544
# 5          3001  0.675676  1.249272
# 6          1001  0.904694  0.356296
# 7          2001  0.911807  0.342043
# 8          3001  0.897582  0.338497

# %%
dataset_path = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pets'
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/retrained_Oxford-IIIT_Pets'
prior_path = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
wandb_project = 'retrained_Oxford-IIIT_Pets'

pattern = re.compile(r'(\w+)_bb_weight_decay=([\d.]+)_clf_weight_decay=([\d.]+(?:e[-+]?\d+)?)_lr_0=([\d.]+)_n=(\d+)_random_state=(\d+)')
for row_index, row in learned_prior_lr.iterrows():
    model_name = row.model_name
    match = pattern.match(model_name)
    prior_type, bb_weight_decay, clf_weight_decay, lr_0, n, random_state = match.groups()
    if not os.path.exists(f'{experiments_path}/{model_name}.csv'):
        print(f'    "python ../src/main_OXPETS.py --bb_weight_decay={bb_weight_decay} --clf_weight_decay={clf_weight_decay} --dataset_path=\'{dataset_path}\' --experiments_path=\'{experiments_path}\' --lr_0={lr_0} --n={n} --model_name=\'{model_name}\' --prior_path=\'{prior_path}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save --wandb --wandb_project=\'{wandb_project}\'"')

# %%
experiments_path = '/cluster/tufts/hugheslab/eharve06/bdl-transfer-learning/experiments/retrained_Oxford-IIIT_Pets'
std_prior_results = get_results(std_prior, experiments_path)
learned_prior_iso_results = get_results(learned_prior_iso, experiments_path)
learned_prior_lr_results = get_results(learned_prior_lr, experiments_path)
results = pd.concat([std_prior_results, learned_prior_iso_results, learned_prior_lr_results])
results
# Out:
#                                           model_name     n      prior_type  \
# 0  nonlearned_lr_0=0.001_n=37_random_state=1001_w...    37      nonlearned
# 1  nonlearned_lr_0=0.001_n=37_random_state=2001_w...    37      nonlearned
# 2  nonlearned_lr_0=0.001_n=37_random_state=3001_w...    37      nonlearned
# 3  nonlearned_lr_0=0.01_n=370_random_state=1001_w...   370      nonlearned
# 4  nonlearned_lr_0=0.001_n=370_random_state=2001_...   370      nonlearned
# 5  nonlearned_lr_0=0.0001_n=370_random_state=3001...   370      nonlearned
# 6  nonlearned_lr_0=0.01_n=3441_random_state=1001_...  3441      nonlearned
# 7  nonlearned_lr_0=0.01_n=3441_random_state=2001_...  3441      nonlearned
# 8  nonlearned_lr_0=0.01_n=3441_random_state=3001_...  3441      nonlearned
# 0  adapted_lr_0=0.1_n=37_random_state=1001_weight...    37         adapted
# 1  adapted_lr_0=0.1_n=37_random_state=2001_weight...    37         adapted
# 2  adapted_lr_0=0.1_n=37_random_state=3001_weight...    37         adapted
# 3  adapted_lr_0=0.01_n=370_random_state=1001_weig...   370         adapted
# 4  adapted_lr_0=0.01_n=370_random_state=2001_weig...   370         adapted
# 5  adapted_lr_0=0.0001_n=370_random_state=3001_we...   370         adapted
# 6  adapted_lr_0=0.01_n=3441_random_state=1001_wei...  3441         adapted
# 7  adapted_lr_0=0.01_n=3441_random_state=2001_wei...  3441         adapted
# 8  adapted_lr_0=0.01_n=3441_random_state=3001_wei...  3441         adapted
# 0  LearnedPriorLR_bb_weight_decay=100000000.0_clf...    37  LearnedPriorLR
# 1  LearnedPriorLR_bb_weight_decay=1000000.0_clf_w...    37  LearnedPriorLR
# 2  LearnedPriorLR_bb_weight_decay=100000000.0_clf...    37  LearnedPriorLR
# 3  LearnedPriorLR_bb_weight_decay=1000000.0_clf_w...   370  LearnedPriorLR
# 4  LearnedPriorLR_bb_weight_decay=10000.0_clf_wei...   370  LearnedPriorLR
# 5  LearnedPriorLR_bb_weight_decay=100.0_clf_weigh...   370  LearnedPriorLR
# 6  LearnedPriorLR_bb_weight_decay=10000.0_clf_wei...  3441  LearnedPriorLR
# 7  LearnedPriorLR_bb_weight_decay=1000.0_clf_weig...  3441  LearnedPriorLR
# 8  LearnedPriorLR_bb_weight_decay=1000.0_clf_weig...  3441  LearnedPriorLR
#
#    random_state  test_acc1  test_nll
# 0          1001   0.172697  3.327513
# 1          2001   0.145260  3.398588
# 2          3001   0.200102  3.250308
# 3          1001   0.575321  1.720191
# 4          2001   0.537177  1.828269
# 5          3001   0.532070  1.782722
# 6          1001   0.864874  0.555606
# 7          2001   0.866187  0.547540
# 8          3001   0.859838  0.655502
# 0          1001   0.070150  3.612332
# 1          2001   0.053620  3.687906
# 2          3001   0.084853  3.560486
# 3          1001   0.577203  1.710178
# 4          2001   0.554506  1.866707
# 5          3001   0.533362  1.778537
# 6          1001   0.854081  0.659033
# 7          2001   0.871910  0.530935
# 8          3001   0.865949  0.555647
# 0          1001   0.062415  3.634729
# 1          2001   0.073044  3.592839
# 2          3001   0.062687  3.634330
# 3          1001   0.576996  1.716005
# 4          2001   0.561733  1.710798
# 5          3001   0.581902  1.639432
# 6          1001   0.878168  0.517852
# 7          2001   0.872717  0.524339
# 8          3001   0.850368  0.528662

# %%
grouped_results = results.groupby(['n', 'prior_type']).agg(lambda x: tuple(x))
columns = ['test_acc1', 'test_nll']
for column in columns:
    grouped_results[f'{column}_mean'] = grouped_results[column].apply(lambda item: np.mean(item))
    grouped_results[f'{column}_std'] = grouped_results[column].apply(lambda item: np.std(item))
    grouped_results[f'{column}_min'] = grouped_results[column].apply(lambda item: np.min(item))
    grouped_results[f'{column}_max'] = grouped_results[column].apply(lambda item: np.max(item))
grouped_results = grouped_results.reset_index()
grouped_results
# Out:
#       n      prior_type                                         model_name  \
# 0    37  LearnedPriorLR  (LearnedPriorLR_bb_weight_decay=100000000.0_cl...
# 1    37         adapted  (adapted_lr_0=0.1_n=37_random_state=1001_weigh...
# 2    37      nonlearned  (nonlearned_lr_0=0.001_n=37_random_state=1001_...
# 3   370  LearnedPriorLR  (LearnedPriorLR_bb_weight_decay=1000000.0_clf_...
# 4   370         adapted  (adapted_lr_0=0.01_n=370_random_state=1001_wei...
# 5   370      nonlearned  (nonlearned_lr_0=0.01_n=370_random_state=1001_...
# 6  3441  LearnedPriorLR  (LearnedPriorLR_bb_weight_decay=10000.0_clf_we...
# 7  3441         adapted  (adapted_lr_0=0.01_n=3441_random_state=1001_we...
# 8  3441      nonlearned  (nonlearned_lr_0=0.01_n=3441_random_state=1001...
#
#          random_state                                          test_acc1  \
# 0  (1001, 2001, 3001)  (0.062414826941314734, 0.07304442627418917, 0....
# 1  (1001, 2001, 3001)  (0.0701496228575706, 0.05362019687891, 0.08485...
# 2  (1001, 2001, 3001)  (0.1726965457201004, 0.1452600657939911, 0.200...
# 3  (1001, 2001, 3001)  (0.5769964577359574, 0.5617334427187637, 0.581...
# 4  (1001, 2001, 3001)  (0.5772032737731934, 0.5545060038566589, 0.533...
# 5  (1001, 2001, 3001)  (0.5753209590911865, 0.537177324295044, 0.5320...
# 6  (1001, 2001, 3001)  (0.8781684390983259, 0.8727173618868737, 0.850...
# 7  (1001, 2001, 3001)  (0.8540814518928528, 0.8719097375869751, 0.865...
# 8  (1001, 2001, 3001)  (0.8648736476898193, 0.8661870360374451, 0.859...
#
#                                             test_nll  test_acc1_mean  \
# 0  (3.6347291752245225, 3.592839194890685, 3.6343...        0.066049
# 1  (3.6123320707413193, 3.6879057203206025, 3.560...        0.069541
# 2  (3.32751329070575, 3.398587943228105, 3.250308...        0.172686
# 3  (1.7160049469115528, 1.7107981094127458, 1.639...        0.573544
# 4  (1.71017842869175, 1.8667065985490665, 1.77853...        0.555024
# 5  (1.7201914414621304, 1.8282694676228457, 1.782...        0.548189
# 6  (0.5178519139565378, 0.5243389157044788, 0.528...        0.867085
# 7  (0.6590327450903536, 0.5309345716593799, 0.555...        0.863980
# 8  (0.5556059793657229, 0.5475396912765294, 0.655...        0.863633
#
#    test_acc1_std  test_acc1_min  test_acc1_max  test_nll_mean  test_nll_std  \
# 0       0.004948       0.062415       0.073044       3.620633      0.019654
# 1       0.012758       0.053620       0.084853       3.620241      0.052319
# 2       0.022389       0.145260       0.200102       3.325470      0.060552
# 3       0.008588       0.561733       0.581902       1.688745      0.034935
# 4       0.017902       0.533362       0.577203       1.785141      0.064073
# 5       0.019298       0.532070       0.575321       1.777061      0.044304
# 6       0.012028       0.850368       0.878168       0.523618      0.004442
# 7       0.007410       0.854081       0.871910       0.581871      0.055486
# 8       0.002737       0.859838       0.866187       0.586216      0.049103
#
#    test_nll_min  test_nll_max
# 0      3.592839      3.634729
# 1      3.560486      3.687906
# 2      3.250308      3.398588
# 3      1.639432      1.716005
# 4      1.710178      1.866707
# 5      1.720191      1.828269
# 6      0.517852      0.528662
# 7      0.530935      0.659033
# 8      0.547540      0.655502

# %%
grouped_results[['n', 'prior_type', 'test_acc1_mean', 'test_acc1_min', 'test_acc1_max']]
# Out:
#       n      prior_type  test_acc1_mean  test_acc1_min  test_acc1_max
# 0    37  LearnedPriorLR        0.066049       0.062415       0.073044
# 1    37         adapted        0.069541       0.053620       0.084853
# 2    37      nonlearned        0.172686       0.145260       0.200102
# 3   370  LearnedPriorLR        0.573544       0.561733       0.581902
# 4   370         adapted        0.555024       0.533362       0.577203
# 5   370      nonlearned        0.548189       0.532070       0.575321
# 6  3441  LearnedPriorLR        0.867085       0.850368       0.878168
# 7  3441         adapted        0.863980       0.854081       0.871910
# 8  3441      nonlearned        0.863633       0.859838       0.866187

# %%
grouped_results[['n', 'prior_type', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#       n      prior_type  test_nll_mean  test_nll_min  test_nll_max
# 0    37  LearnedPriorLR       3.620633      3.592839      3.634729
# 1    37         adapted       3.620241      3.560486      3.687906
# 2    37      nonlearned       3.325470      3.250308      3.398588
# 3   370  LearnedPriorLR       1.688745      1.639432      1.716005
# 4   370         adapted       1.785141      1.710178      1.866707
# 5   370      nonlearned       1.777061      1.720191      1.828269
# 6  3441  LearnedPriorLR       0.523618      0.517852      0.528662
# 7  3441         adapted       0.581871      0.530935      0.659033
# 8  3441      nonlearned       0.586216      0.547540      0.655502
